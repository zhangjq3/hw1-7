# %% [markdown]
# ## Perceptron Learning Algorithm
#
# The perceptron is a simple supervised machine learning algorithm and one of the earliest neural network architectures. It was introduced by Rosenblatt in the late 1950s. A perceptron represents a binary linear classifier that maps a set of training examples (of $d$ dimensional input vectors) onto binary output values using a $d-1$ dimensional hyperplane. But Today, we will implement **Multi-Classes Perceptron Learning Algorithm**
# **Given:**
# * dataset $\{(x^i, y^i)\}$, $i \in (1, M)$
# * $x^i$ is $d$ dimension vector, $x^i = (x^i_1, \dots x^i_d)$
# * $y^i$ is multi-class target varible $y^i \in \{0,1,2\}$
#
# A perceptron is trained using gradient descent. The training algorithm has different steps. In the beginning (step 0) the model parameters are initialized. The other steps (see below) are repeated for a specified number of training iterations or until the parameters have converged.
#
# **Step0:** Initial the weight vector and bias with zeros
# **Step1:** Compute the linear combination of the input features and weight. $y^i_{pred} = \arg\max_k W_k*x^i + b$
# **Step2:** Compute the gradients for parameters $W_k$, $b$. **Derive the parameter update equation Here (5 points)**
#
# ##################################
# TODO: Derive you answer hear
#
# #################################

# %%
from sklearn import datasets
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

np.random.seed(0)
random.seed(0)

# %%
iris = datasets.load_iris()
X = iris.data
print(type(X))
y = iris.target
y = np.array(y)
print('X_Shape:', X.shape)
print('y_Shape:', y.shape)
print('Label Space:', np.unique(y))
# Out:
# <class 'numpy.ndarray'>
# X_Shape: (150, 4)
# y_Shape: (150,)
# Label Space: [0 1 2]

# %%
## split the training set and test set
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=0)
print('X_train_Shape:', X_train.shape)
print('X_test_Shape:',  X_test.shape)
print('y_train_Shape:', y_train.shape)
print('y_test_Shape:',  y_test.shape)
print(type(y_train))
# Out:
# X_train_Shape: (105, 4)
# X_test_Shape: (45, 4)
# y_train_Shape: (105,)
# y_test_Shape: (45,)
# <class 'numpy.ndarray'>

# %%
class MultiClsPLA(object):
    
    ## We recommend to absorb the bias into weight.  W = [w, b]
    
    def __init__(self, X_train, y_train, X_test, y_test, lr, num_epoch, weight_dimension, num_cls):
        super(MultiClsPLA, self).__init__()
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.y_test = y_test
        self.weight = self.initial_weight(weight_dimension, num_cls)
        self.sample_mean = np.mean(self.X_train, 0)
        self.sample_std = np.std(self.X_train, 0)
        self.num_epoch = num_epoch
        self.lr = lr
        self.total_acc_train = []
        self.total_acc_tst = []
          
    def initial_weight(self, weight_dimension, num_cls):

        
        
        #########################################
        ##  ToDO: Initialize the weight with   ##
        ##  samll std and zero mean gaussian   ##
        #########################################
        s=(weight_dimension[0],weight_dimension[1])
        weight = np.random.normal(0, 0.01, s)
        
     
        return weight
        
    def data_preprocessing(self, data):
        #####################################
        ##  ToDO: Normlize the data        ##
        #####################################
        norm_data = (data - self.sample_mean) / self.sample_std
        return norm_data
    
    def train_step(self, X_train, y_train, shuffle_idx):
        #X_train = self.data_preprocessing(data=X_train)
        np.random.shuffle(shuffle_idx)
        X_train = X_train[shuffle_idx]
        y_train = y_train[shuffle_idx]
        
        train_acc = None
        ##############################################
        ## TODO: to implement the training process  ##
        ## and update the weights                   ##
        ##############################################
        layer1 = np.dot(X_train,self.weight)

        y_pred = np.argmax(layer1,axis=1)
        scores_pred = [layer1[i][y_pred[i]] for i in range(len(y_pred))]
        scores_y = [layer1[i][y_train[i]] for i in range(len(y_train))]
        loss_vector = np.array(scores_pred) - np.array(scores_y)
        loss = np.sum(loss_vector)
        dW = np.zeros_like(self.weight)

        for i in range(len(y_train)):
            pred_index = y_pred[i]
            label_index = y_train[i]
            dW[:,pred_index] = X_train[i][:].T
            dW[:,label_index] = - X_train[i][:].T
                
        self.weight = self.weight - self.lr * dW
        
        num_cor = np.sum(y_pred == y_train)
        train_acc = num_cor / len(y_train)
        
        
        
        return train_acc
        
    def test_step(self, X_test, y_test):
        
        
        #X_test = self.data_preprocessing(data=X_test)
        num_sample = X_test.shape[0]
        test_acc = None
       
        
        
        #########################################
        ##  ToDO: Evaluate the test set and    ##
        ##  return the test acc                ##
        #########################################
        W = self.weight
        layer1 = np.dot(X_test,W)
        y_pred = np.argmax(layer1,axis=1)
        
        corr = np.sum(y_pred == y_test) 
        
        test_acc = corr / len(y_test)
        
           
        return test_acc
        
    def train(self):
        
        print("start")
        self.X_train = self.data_preprocessing(data=self.X_train)
        self.X_test = self.data_preprocessing(data=self.X_test)
        num_sample = self.X_train.shape[0]
        
        ######################################################
        ### TODO: In order to absorb the bias into weights ###
        ###  we need to modify the input data.             ###
        ###  So You need to transform the input data       ###
        ######################################################
        train_bias = np.ones(num_sample)
        test_bias = np.ones(len(self.X_test))
        self.X_train = np.column_stack((self.X_train,train_bias))
        self.X_test = np.column_stack((self.X_test,test_bias))
        
        shuffle_index = np.array(range(0, num_sample))
        for epoch in range(self.num_epoch):
            

            training_acc = self.train_step(X_train=self.X_train, y_train=self.y_train, shuffle_idx=shuffle_index)            
            tst_acc = self.test_step(X_test=self.X_test,  y_test=self.y_test)
            self.total_acc_train.append(training_acc)
            self.total_acc_tst.append(tst_acc)
            print('epoch:', epoch, 'traing_acc:%.3f'%training_acc, 'tst_acc:%.3f'%tst_acc)
    
    def vis_acc_curve(self):
        train_acc = np.array(self.total_acc_train)
        tst_acc = np.array(self.total_acc_tst)
        plt.plot(train_acc)
        plt.plot(tst_acc)
        plt.legend(['train_acc', 'tst_acc'])
        plt.show()

# %%
np.random.seed(0)
random.seed(0)
#######################################################
### TODO: 
### 1. You need to import the model and pass some parameters. 
### 2. Then training the model with some epoches.
### 3. Visualize the training acc and test acc verus epoches

mulpla = MultiClsPLA(X_train, y_train, X_test, y_test, lr=0.0005, num_epoch=100, weight_dimension=(5,3), num_cls=3)
mulpla.train()
mulpla.vis_acc_curve()
# Out:
# start
# epoch: 0 traing_acc:0.143 tst_acc:0.111
# epoch: 1 traing_acc:0.152 tst_acc:0.111
# epoch: 2 traing_acc:0.162 tst_acc:0.133
# epoch: 3 traing_acc:0.210 tst_acc:0.178
# epoch: 4 traing_acc:0.229 tst_acc:0.267
# epoch: 5 traing_acc:0.286 tst_acc:0.444
# epoch: 6 traing_acc:0.390 tst_acc:0.489
# epoch: 7 traing_acc:0.457 tst_acc:0.511
# epoch: 8 traing_acc:0.514 tst_acc:0.556
# epoch: 9 traing_acc:0.590 tst_acc:0.578
# epoch: 10 traing_acc:0.590 tst_acc:0.578
# epoch: 11 traing_acc:0.610 tst_acc:0.600
# epoch: 12 traing_acc:0.610 tst_acc:0.600
# epoch: 13 traing_acc:0.619 tst_acc:0.600
# epoch: 14 traing_acc:0.619 tst_acc:0.600
# epoch: 15 traing_acc:0.619 tst_acc:0.600
# epoch: 16 traing_acc:0.648 tst_acc:0.600
# epoch: 17 traing_acc:0.657 tst_acc:0.600
# epoch: 18 traing_acc:0.667 tst_acc:0.600
# epoch: 19 traing_acc:0.667 tst_acc:0.622
# epoch: 20 traing_acc:0.667 tst_acc:0.644
# epoch: 21 traing_acc:0.686 tst_acc:0.622
# epoch: 22 traing_acc:0.676 tst_acc:0.622
# epoch: 23 traing_acc:0.676 tst_acc:0.644
# epoch: 24 traing_acc:0.695 tst_acc:0.644
# epoch: 25 traing_acc:0.705 tst_acc:0.644
# epoch: 26 traing_acc:0.743 tst_acc:0.689
# epoch: 27 traing_acc:0.771 tst_acc:0.778
# epoch: 28 traing_acc:0.810 tst_acc:0.822
# epoch: 29 traing_acc:0.838 tst_acc:0.800
# epoch: 30 traing_acc:0.829 tst_acc:0.800
# epoch: 31 traing_acc:0.829 tst_acc:0.822
# epoch: 32 traing_acc:0.838 tst_acc:0.822
# epoch: 33 traing_acc:0.848 tst_acc:0.844
# epoch: 34 traing_acc:0.848 tst_acc:0.844
# epoch: 35 traing_acc:0.848 tst_acc:0.844
# epoch: 36 traing_acc:0.838 tst_acc:0.844
# epoch: 37 traing_acc:0.838 tst_acc:0.844
# epoch: 38 traing_acc:0.848 tst_acc:0.889
# epoch: 39 traing_acc:0.857 tst_acc:0.867
# epoch: 40 traing_acc:0.857 tst_acc:0.867
# epoch: 41 traing_acc:0.857 tst_acc:0.867
# epoch: 42 traing_acc:0.857 tst_acc:0.844
# epoch: 43 traing_acc:0.848 tst_acc:0.844
# epoch: 44 traing_acc:0.857 tst_acc:0.844
# epoch: 45 traing_acc:0.848 tst_acc:0.867
# epoch: 46 traing_acc:0.857 tst_acc:0.844
# epoch: 47 traing_acc:0.857 tst_acc:0.844
# epoch: 48 traing_acc:0.857 tst_acc:0.844
# epoch: 49 traing_acc:0.857 tst_acc:0.867
# epoch: 50 traing_acc:0.867 tst_acc:0.844
# epoch: 51 traing_acc:0.857 tst_acc:0.844
# epoch: 52 traing_acc:0.867 tst_acc:0.844
# epoch: 53 traing_acc:0.867 tst_acc:0.844
# epoch: 54 traing_acc:0.867 tst_acc:0.889
# epoch: 55 traing_acc:0.876 tst_acc:0.844
# epoch: 56 traing_acc:0.848 tst_acc:0.844
# epoch: 57 traing_acc:0.829 tst_acc:0.822
# epoch: 58 traing_acc:0.829 tst_acc:0.800
# epoch: 59 traing_acc:0.829 tst_acc:0.800
# epoch: 60 traing_acc:0.829 tst_acc:0.800
# epoch: 61 traing_acc:0.829 tst_acc:0.800
# epoch: 62 traing_acc:0.829 tst_acc:0.800
# epoch: 63 traing_acc:0.829 tst_acc:0.800
# epoch: 64 traing_acc:0.829 tst_acc:0.800
# epoch: 65 traing_acc:0.829 tst_acc:0.800
# epoch: 66 traing_acc:0.829 tst_acc:0.800
# epoch: 67 traing_acc:0.829 tst_acc:0.800
# epoch: 68 traing_acc:0.829 tst_acc:0.800
# epoch: 69 traing_acc:0.829 tst_acc:0.800
# epoch: 70 traing_acc:0.838 tst_acc:0.800
# epoch: 71 traing_acc:0.838 tst_acc:0.800
# epoch: 72 traing_acc:0.838 tst_acc:0.800
# epoch: 73 traing_acc:0.838 tst_acc:0.822
# epoch: 74 traing_acc:0.848 tst_acc:0.822
# epoch: 75 traing_acc:0.848 tst_acc:0.844
# epoch: 76 traing_acc:0.838 tst_acc:0.822
# epoch: 77 traing_acc:0.838 tst_acc:0.822
# epoch: 78 traing_acc:0.838 tst_acc:0.822
# epoch: 79 traing_acc:0.838 tst_acc:0.822
# epoch: 80 traing_acc:0.838 tst_acc:0.822
# epoch: 81 traing_acc:0.829 tst_acc:0.822
# epoch: 82 traing_acc:0.829 tst_acc:0.822
# epoch: 83 traing_acc:0.838 tst_acc:0.822
# epoch: 84 traing_acc:0.838 tst_acc:0.822
# epoch: 85 traing_acc:0.838 tst_acc:0.822
# epoch: 86 traing_acc:0.838 tst_acc:0.822
# epoch: 87 traing_acc:0.838 tst_acc:0.844
# epoch: 88 traing_acc:0.838 tst_acc:0.822
# epoch: 89 traing_acc:0.838 tst_acc:0.822
# epoch: 90 traing_acc:0.829 tst_acc:0.822
# epoch: 91 traing_acc:0.838 tst_acc:0.822
# epoch: 92 traing_acc:0.838 tst_acc:0.844
# epoch: 93 traing_acc:0.838 tst_acc:0.844
# epoch: 94 traing_acc:0.838 tst_acc:0.844
# epoch: 95 traing_acc:0.838 tst_acc:0.822
# epoch: 96 traing_acc:0.838 tst_acc:0.822
# epoch: 97 traing_acc:0.838 tst_acc:0.822
# epoch: 98 traing_acc:0.829 tst_acc:0.822
# epoch: 99 traing_acc:0.829 tst_acc:0.822
